# %%
# Landslide Risk Prediction (MLRP-KG inspired)
# Week 1 Implementation (Basic Version)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

# %%
data = {
    "slope_angle": [10, 30, 45, 20, 50, 60, 15, 35],
    "rainfall": [100, 200, 300, 150, 400, 500, 120, 250],
    "soil_type": [1, 2, 1, 2, 1, 2, 1, 2],
    "landslide": [0, 1, 1, 0, 1, 1, 0, 1]
}

df = pd.DataFrame(data)
df
# Out:
#    slope_angle  rainfall  soil_type  landslide
# 0           10       100          1          0
# 1           30       200          2          1
# 2           45       300          1          1
# 3           20       150          2          0
# 4           50       400          1          1
# 5           60       500          2          1
# 6           15       120          1          0
# 7           35       250          2          1

# %%
df["slope_rainfall"] = df["slope_angle"] * df["rainfall"]

# %%
X = df.drop("landslide", axis=1)
y = df["landslide"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = GradientBoostingClassifier()
model.fit(X_train, y_train)

preds = model.predict(X_test)

# %%
accuracy_score(y_test, preds)
# Out:
# 1.0
